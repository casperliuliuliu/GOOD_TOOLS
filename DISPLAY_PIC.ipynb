# %%
from IPython import display
display.Image('./TEST_DATA/image.png')

# %%
from PIL import Image
Image.open('./TEST_DATA/image.png')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=235x214>
