# %%
import os
import shutil

def move_files_out(source_folder, destination_folder):
    # Ensure the source folder exists
    if not os.path.exists(source_folder):
        print(f"Source folder '{source_folder}' does not exist.")
        return
    
    # Ensure the destination folder exists or create it
    if not os.path.exists(destination_folder):
        os.makedirs(destination_folder)

    # List all files in the source folder
    files = os.listdir(source_folder)

    # Move each file from the source to the destination folder
    for file_name in files:
        source_file = os.path.join(source_folder, file_name)
        destination_file = os.path.join(destination_folder, file_name)

        # Check if the item is a file (not a directory)
        if os.path.isfile(source_file):
            shutil.move(source_file, destination_file)
            print(f"Moved '{file_name}' from '{source_folder}' to '{destination_folder}'")


source_folder = "E:\\Tiff\\2nd\\MGN-Anonymize"
source_folder = "E:\\Tiff\\4th\\MGN"
destination_folder = "E:\\Data\\Taichung\\MGN"

# for source in os.listdir(destination_folder):
#     source_folder = os.path.join(destination_folder, source)

#     if os.path.isdir(source_folder):  # Check if it's a directory
#         print(f"Contents of {source_folder}:")
#         print(os.listdir(source_folder))
#         for item in os.listdir(source_folder):
#             print(item)
        # move_files_out(source_folder, destination_folder)
move_files_out(source_folder, destination_folder)
# Out:
# Moved 'S0920152,H06,090713_Wholeslide_Default_Extended.tif' from 'E:\Tiff\4th\MGN' to 'E:\Data\Taichung\MGN'
# Moved 'S0920152,S18,090713_Wholeslide_Default_Extended.tif' from 'E:\Tiff\4th\MGN' to 'E:\Data\Taichung\MGN'
# Moved 'S0920152,S20,090713_Wholeslide_Default_Extended.tif' from 'E:\Tiff\4th\MGN' to 'E:\Data\Taichung\MGN'
# Moved 'S0920327,H06,090714_Wholeslide_Default_Extended.tif' from 'E:\Tiff\4th\MGN' to 'E:\Data\Taichung\MGN'
# Moved 'S0920327,S18,090714_Wholeslide_Default_Extended.tif' from 'E:\Tiff\4th\MGN' to 'E:\Data\Taichung\MGN'
# Moved 'S0920327,S20,090714_Wholeslide_Default_Extended.tif' from 'E:\Tiff\4th\MGN' to 'E:\Data\Taichung\MGN'
# Moved 'S0922039,H06,090727_Wholeslide_Default_Extended.tif' from 'E:\Tiff\4th\MGN' to 'E:\Data\Taichung\MGN'
# Moved 'S0922039,S18,090727_Wholeslide_Default_Extended.tif' from 'E:\Tiff\4th\MGN' to 'E:\Data\Taichung\MGN'
# Moved 'S0922039,S20,090727_Wholeslide_Default_Extended.tif' from 'E:\Tiff\4th\MGN' to 'E:\Data\Taichung\MGN'
# ...
